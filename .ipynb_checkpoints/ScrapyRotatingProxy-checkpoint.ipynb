# %%
from urllib.request import Request, urlopen
from bs4 import BeautifulSoup
from fake_useragent import UserAgent
import random

# %%
ua = UserAgent() # From here we generate a random user agent
proxies = [] # Will contain proxies [ip, port]

# Main function
def main():
  # Retrieve latest proxies
  proxies_req = Request('https://www.sslproxies.org/')
  proxies_req.add_header('User-Agent', ua.random)
  proxies_doc = urlopen(proxies_req).read().decode('utf8')

  soup = BeautifulSoup(proxies_doc, 'html.parser')
  proxies_table = soup.find(id='proxylisttable')

  # Save proxies in the array
  for row in proxies_table.tbody.find_all('tr'):
    proxies.append({
      'ip':   row.find_all('td')[0].string,
      'port': row.find_all('td')[1].string
    })

  # Choose a random proxy
  proxy_index = random_proxy()
  proxy = proxies[proxy_index]

  for n in range(1, 100):
    url = "http://www.lsdag.com/COMMON/ajax/Ajax.ashx?obj=Lsda&type=LsdaSearch&curr=%s&numPerPage=20&title=&sn=&guanzhi=&zerenzhe=&yuanjinian=&_=1542642296731" %n
    # req = Request('http://icanhazip.com')
    req = Request(url)
    file = open(/home/yxd/Documents/webcrawler/archive_data/%s.txt'%i,'w+',encoding='utf-8')
    file.wr
    req.set_proxy(proxy['ip'] + ':' + proxy['port'], 'http')

    # Every 10 requests, generate a new proxy
    if n % 10 == 0:
      proxy_index = random_proxy()
      proxy = proxies[proxy_index]

    # Make the call
    try:
      my_ip = urlopen(req).read().decode('utf8')
      print('#' + str(n) + ': ' + my_ip)
    except: # If error, delete this proxy and find another one
      del proxies[proxy_index]
      print('Proxy ' + proxy['ip'] + ':' + proxy['port'] + ' deleted.')
      proxy_index = random_proxy()
      proxy = proxies[proxy_index]

# Retrieve a random index proxy (we need the index to delete it if not working)
def random_proxy():
  return random.randint(0, len(proxies) - 1)

if __name__ == '__main__':
  main()
# Out:
# #1: [{"id":null,"title":"为题报交印起程赴黔日期事","sn":"02-01-006-000001-0001","guanzhi":"署理四川川北镇总兵","zerenzhe":"王廷诏","yuanjinian":"乾隆元年正月初二日"},{"id":null,"title":"为奉旨补授四川提督谢恩事","sn":"02-01-006-000001-0002","guanzhi":"四川提督","zerenzhe":"黄廷桂","yuanjinian":"乾隆元年正月初八日"},{"id":null,"title":"为题报赍缴扬威将军银印敕谕日期事","sn":"02-01-006-000001-0003","guanzhi":"贵州提督","zerenzhe":"哈元生","yuanjinian":"乾隆元年正月十一日"},{"id":null,"title":"为奉诏封赠荫子谢恩事","sn":"02-01-006-000001-0004","guanzhi":"福州左翼副都统","zerenzhe":"陈世璠","yuanjinian":"乾隆元年正月二十日"},{"id":null,"title":"为奉诏封赠谢恩事","sn":"02-01-006-000001-0005","guanzhi":"护理福建金门总兵","zerenzhe":"高得志","yuanjinian":"乾隆元年正月二十日"},{"id":null,"title":"为汇报雍正十三年份署理武定营游击李成芳请复本姓事","sn":"02-01-006-000001-0006","guanzhi":"山东登州镇总兵","zerenzhe":"马世龙","yuanjinian":"乾隆元年正月二十日"},{"id":null,"title":"为题请参处代防益都县汛把总刘玉西疏防盗犯刘二越狱脱逃事","sn":"02-01-006-000001-0007","guanzhi":"山东登州镇总兵","zerenzhe":"马世龙","yuanjinian":"乾隆元年正月二十一日"},{"id":null,"title":"为题报福建台湾镇北路左营守备王世俊病故事","sn":"02-01-006-000001-0008","guanzhi":"闽浙总督",
# ...
